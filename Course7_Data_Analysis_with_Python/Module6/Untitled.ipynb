# %% [markdown]
# 1. Question 1
#    What type of file saves data in a text-based tabular format?
#    - [ ] XLSX
#    - [x] CSV
#    - [ ] PDF
#    - [ ] HTML
#
# 2. Question 2
#    What is the Python library Scikit-learn primarily designed for?
#    - [x] Statistical modeling, including regression and classification
#    - [ ] Operations on matrices
#    - [ ] Exploratory data analysis
#    - [ ] Fast array processing
#
# 3. Question 3
#    What is a file path?
#    - [ ] Describes the schema of the data
#    - [x] Describes where the data is stored
#    - [ ] Indicates the way data is encoded
#    - [ ] Describes the format of the data
#
# 4. Question 4
#    What does the df.head() method return?
#    - [ ] It returns the last five columns of the data frame
#    - [x] It returns the first five columns of the data frame
#    - [ ] It returns the last five rows of the data frame
#    - [ ] It returns the first five rows of the data frame
#
# 5. Question 5
#    The Pandas library allows us to read what?
#    - [ ] File types
#    - [ ] Only rows
#    - [x] Data sets into a data frame
#    - [ ] Only headers
#
# 6. Question 6
#    The Scikit-learn library is mostly used for what?
#    - [ ] Statistical modeling
#    - [x] Machine learning algorithms
#    - [ ] Data visualization
#    - [ ] Data analysis
#
# 7. Question 7
#    What is the output of the following code segment of the data frame df?
#    `df.tail(10)`
#    - [ ] It returns the first 10 rows of the data frame
#    - [ ] It returns all of the rows of the data frame
#    - [x] It returns the last 10 rows of the data frame
#    - [ ] It returns the header of the data frame
#
# 8. Question 8
#    What is the dropna() method used for?
#    - [x] Dropping missing values
#    - [ ] Replacing missing values
#    - [ ] Dropping specified values
#    - [ ] Identifying missing values
#
# 9. Question 9
#    Which type of plot is binning best suited to graph?
#    - [ ] Line plot
#    - [ ] Scatter plot
#    - [x] Histogram
#    - [ ] Box plot
#
# 10. Question 10
#     What is the primary purpose of standardizing a set of values?
#     - [x] It places different variables on the same scale, allowing you to compare them more easily.
#     - [ ] To find how well a data set fits a model.
#     - [ ] So you can see the spread of the data set and identify outliers.
#     - [ ] To see how many standard deviations each value is from the mean.
#
# 11. Question 11
#     What is it called when you subtract the mean from the values in a data set and divide by the standard deviation?
#     - [ ] One-hot encoding
#     - [ ] Binning
#     - [ ] Min-max method
#     - [x] Data standardization
#
# 12. Question 12
#     What task does the following line of code perform in the data frame df?
#     `df['peak-rpm'].replace(np.nan, 5, inplace=True)`
#     - [ ] Renames the column 'peak-rpm' to 5
#     - [x] Replaces the not a number values with 5 in the column 'peak-rpm'
#     - [ ] Replaces the values equal to 5 in the column 'peak-rpm' with the value ‘nan’
#     - [ ] Adds 5 to the values in the column 'peak-rpm'
#
# 13. Question 13
#     What does a negative linear relationship between an input variable and an output variable imply?
#     - [x] That as the input increases, the output decreases at about the same rate.
#     - [ ] That as the input increases, the output increases at about the same rate.
#     - [ ] The output does not adequately explain the input.
#     - [ ] That as the input increases, the output decreases at an ever-increasing rate.
#
# 14. Question 14
#     What is the interquartile range of a data set?
#     - [x] The data between the upper and lower quartiles represents the interquartile range.
#     - [ ] The range of the data, split into four equal-sized groups
#     - [ ] The middle of the data
#     - [ ] The difference in the range of values in the uppermost quartile with the range of values in the lower-most quartile
#
# 15. Question 15
#     If the predicted function is:
#     \(\hat{y} = b_0x^3 + b_1x^2 + b_2x + b_3\)
#     The method is:
#     - [x] Polynomial Regression
#     - [ ] Exponential Regression
#     - [ ] Linear regression
#     - [ ] Multiple Linear Regression
#
# 16. Question 16
#     Say you are trying to predict the price of a car based on its gas mileage, and you find an equation in terms of  and \(x\) to \(\hat{y}\) predict these values. What is this equation called?
#     - [ ] Mean square error
#     - [ ] Model estimator
#     - [ ] Coefficient of determination
#     - [ ] Multiple linear regression
#
# 17. Question 17
#     Why might you want to use a histogram in conjunction with your residuals?
#     - [x] To look at the distribution of your residuals in a multiple linear regression.
#     - [ ] To see if there is curvature in your predicted values.
#     - [ ] To standardize your output values.
#     - [ ] To calculate the accuracy of your model.
#
# 18. Question 18
#     Say you have multiple polynomials that seem to fit your data. What type of graph can you use to help determine which order polynomial is the best fit for your data?
#     - [ ] The order of the polynomials on the x-axis, and the MSE on the y-axis with your testing data set.
#     - [ ] The order of the polynomials on the x-axis, and the MSE on the y-axis with your training data set.
#     - [x] The input values of your testing data on the x-axis and their MSE values on the y-axis.
#     - [ ] The input values of your training data on the x-axis and their MSE values on the y-axis.
#
# 19. Question 19
#     If your alpha value is large, what does that indicate?
#     - [ ] The bigger the alpha, the better the fit.
#     - [ ] Your model is overfitted.
#     - [x] Your model is underfitted.
#     - [ ] Your model needs to be a lower-order function.
#
# 20. Question 20
#     What is one of the arguments of the GridSearchCV() method?
#     - [ ] The normalized input values from your data set.
#     - [ ] A Python dictionary where the key is the column header of your data set, and the values are the different values in that column.
#     - [ ] A data frame containing different possible models and their R2 values.
#     - [x] A Python dictionary with the key-value pair of the hyperparameter and a list of its possible values.
