# %% [markdown]
# # Data Visualization
#
# - It's the graphical representation of data, using charts, graphs, maps, and more.
# - It helps us understand complex datasets and communicate insights effectively.
#
# **Benefits of Data Visualization:**
#
# - **Uncover patterns and trends:** Visualizations reveal hidden relationships in data.
# - **Enhance communication:** Data stories become clearer and more engaging.
# - **Informed decision-making:** By seeing data visually, we can make better choices.
#
# **Real-World Examples:**
#
# - The New York Times uses data visualization to track COVID-19 cases and vaccinations.
# - Airbnb employs bar graphs to help hosts set optimal listing prices.
# - Spotify Pie allows users to see their listening habits through customized pie charts.
# - Netflix leverages dashboards with various visualizations to understand operations and audience preferences.
#
# **Importance of Data Visualization:**
#
# - It benefits various fields like business, healthcare, education, and research.
# - It empowers companies, governments, scientists, and individuals to gain valuable insights.
#
# **Best Practices for Effective Visualization:**
#
# - **Choose the right chart type:** Match the chart to the data you're presenting.
# - **Keep it simple and clear:** Avoid cluttering the visualization with unnecessary elements.
# - **Label axes and provide context:** Ensure clear titles, legends, and labels for clarity.
# - **Focus on the main point:** Don't overwhelm viewers with too much information.
# - **Consider your audience:** Tailor the visualization to their understanding.
#
# **Additional Notes:**
#
# - The video highlights bad data visualization examples to illustrate best practices.
# - Darkhorse Analytics is a company known for its focus on clear and impactful data visualizations.
#
# I hope this summary is helpful!

# %% [markdown]
# # Types of Plots
#
# Welcome to types of plots. After watching this video, you'll be able to:
#
# - Explore different types of plots available for visualizing data.
# - Identify the characteristics and appropriate use cases for each type of plot.
#
# As we know, data visualization represents data using visual formats like graphs, charts, and maps. It effectively communicates information, trends, and insights concisely. It also uncovers patterns, identifies trends, and simplifies complex information for easy understanding. Let's now explore the different types of plots:
#
# ## Line Plot
# A line plot, also known as a line chart, displays data as a series of data points connected by straight lines. Line plots display trends, such as stock market fluctuations or temperature changes over time. They compare datasets with a continuous independent variable like age or time. Line plots illustrate cause and effect relationships, such as sales revenue changes based on marketing budget. They also visualize continuous data, like height measurements over time. Line plots can be misleading if the scales on the axes are not carefully chosen to reflect the data accurately. The line plot shows a downfall in immigration trends in 1998; however, if you correct the scale on the y-axis to start with zero, as in this plot, you'll see that the actual trend is not that alarming.
#
# ## Bar Plot
# A bar plot, also known as a bar chart, displays data using rectangular bars, where the height or length of the bars represents the magnitude of the data. The bars can be oriented either vertically or horizontally. A vertically oriented bar chart is often referred to as a vertical bar chart or a column chart. If you're looking for an effective way to compare data, bar plots are ideal for comparing different categories or groups. They excel with discrete data, like comparing sales revenue by product. They show how different categories contribute to the whole and rankings, such as sales percentage or budget allocation. Bar plots can visualize data that you can easily rank, like displaying the bestselling books in the market. Their simplicity and interpretability make them favored for data visualization. Inaccurate bar choices or axis scales can lead to misleading plots. In this bar plot, the y-axis starting at six makes the difference between the values in 1995 and 1998 seem larger than it actually is. However, when the y-axis starts at zero, the plot accurately represents the data without misleading the viewer.
#
# ## Scatter Plot
# A scatter plot is a type of plot that presents values for two variables for a set of data using Cartesian coordinates. The data points are displayed as a collection of points, where one variable's value determines the position on the horizontal axis and the other variable's value determines the position on the vertical axis. When can you use a scatter plot? Let's explore some options:
# - You can use it for examining the relationship between two continuous variables like temperature and energy consumption.
# - Investigating patterns or trends in data, such as house prices versus size.
# - Detecting outliers or unusual observations such as outliers in test scores or abnormal stock behavior.
# - Visualizing data with many observations to identify clusters or groups and exploring complex data.
# Outliers significantly impact interpretation, requiring consideration of their inclusion or exclusion. On the screen, the data is plotted with and without outliers. With outliers, it shows two clusters, but removing outliers makes the remaining data more visible. Proper outlier handling enhances accuracy and meaningful insights in scatter plots.
#
# ## Box Plot
# A box plot, also known as a box and whisker plot, is a type of plot that displays the distribution of a dataset along with key statistical measures. It consists of a box, representing the interquartile range (IQR), a line inside the box representing the median, and lines whiskers extending from the box to indicate the range of the data, excluding outliers. Outliers may be represented as individual data points beyond the whiskers. Let's look at some scenarios where box plots come in handy:
# - While comparing the distribution of a continuous variable across different categories or groups. For example, employees' salaries across departments.
# - Examining spread and skewness of the dataset.
# - Visualizing quartiles and outliers, identifying and analyzing potential outliers within a dataset.
# - Visualizing summary statistics: median, quartiles, range in a concise and informative manner.
# - Comparing distributions of multiple variables in datasets side by side.
# Remember, box plots provide valuable information about outliers, such as their presence and extent. Ignoring or mishandling outliers can distort the interpretation of the data and mask important insights, the same as with scatter plots.
#
# ## Histogram
# A histogram is a graphical representation of the distribution of a dataset, showing the frequency or relative frequency of values within specific intervals. It consists of bars, where the height represents the data count in each interval. Histograms offer valuable insights into data distribution, outliers, skewness, and variability. They visually depict the shape of the data, whether it's symmetric, skewed, or bimodal. Skewness can be assessed by examining the histogram's shape. Histograms also showcase data variability, allowing you to observe concentrations, gaps, and clusters that reveal patterns or subgroups. Apart from issues with scale and inadequate labeling, be careful while choosing the bins to create a histogram. We have generated a random dataset and created three histograms, with three different binning options. Too few bins (five, represented in green color), an optimal number of bins (20, represented in blue), and too many bins (50, the yellow one). By comparing these histograms, you can observe how the choice of binning affects the representation of the data distribution and results in a misleading representation of the data. Selecting too few or too many bins can oversimplify or overcomplicate the distribution, respectively.
#
# In this video, you learned that there are various types of plots commonly used in data visualization:
# - Line plots capture trends and changes over time, allowing us to see patterns and fluctuations.
# - Bar plots compare categories or groups, providing a visual comparison of their values.
# - Scatter plots explore relationships between variables, helping us identify correlations or trends.
# - Box plots display the distribution of data, showcasing the median, quartiles, and outliers.
# - Histograms illustrate the distribution of data within specific intervals, allowing us to understand its shape and concentration.

# %% [markdown]
# **Cool Data Plotting Tools in Python**
#
# This video is about different ways to draw pictures (plots) of your data in Python. Here are some popular tools:
#
# * **Matplotlib:** This is the "Swiss Army Knife" of plotting tools. It can draw almost any kind of plot, and you can change lots of things about how it looks.
# * **Pandas:** This is a tool for working with tables of data. It also has some basic plotting features that are handy for quickly looking at your data.
# * **Seaborn:** This is built on top of Matplotlib, but it makes it easier to draw fancy statistical plots. It also picks nice colors and makes your plots look good.
# * **Folium:** This one is for maps! It lets you create interactive maps that you can zoom in and out of and click on.
# * **Plotly:** Want to make your plots interactive? Plotly is your friend. You can create plots that people can play with in their web browser.
# * **PyWaffle:** This one is for a specific kind of plot called a waffle chart. It's a fun way to show how something is divided up into different categories.

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# %%
plt.plot(x, y)

# %%
plt.plot(5,5,'o')

# %%
import pandas as pd

# %% [markdown]
# # Introduction to Matplotlib
#
# Welcome to the introduction to Matplotlib. After watching this video, you'll be able to explain what Matplotlib is, why it was created, and describe its uses.
#
# ## What is Matplotlib?
#
# Matplotlib is one of the most widely used data visualization libraries in Python. It was created by John Hunter, an American neurobiologist, as a replacement for proprietary software his research team used for analyzing electroencephalography (EEG) and electrocorticography (ECoG) signals. Initially developed as a tool for EEG and ECoG visualization, Matplotlib evolved into a comprehensive data visualization library akin to Matlab, featuring a scripting interface for quick and easy generation of graphics.
#
# ## Uses of Matplotlib
#
# Matplotlib is versatile and can be integrated into various environments, including:
# - Python scripts
# - Python and IPython shells
# - Web application servers
# - Graphical user interface (GUI) toolkits
# - Jupyter Notebooks
#
# ## Matplotlib Architecture
#
# Matplotlib's architecture consists of three main layers:
#
# ### 1. Backend Layer
# - **FigureCanvas**: Defines the area on which the figure is drawn.
# - **Renderer**: Knows how to draw on the FigureCanvas.
# - **Event**: Handles user inputs such as keyboard strokes and mouse clicks.
#
# ### 2. Artist Layer
# The artist layer is where the heavy lifting happens. Everything visible in a Matplotlib figure is an artist instance. There are two types of artist objects:
# - **Primitive Artists**: `Line2D`, `Rectangle`, `Circle`, `Text`
# - **Composite Artists**: `Axis`, `Tick`, `Axes`, `Figure`
#
# ### 3. Scripting Layer
# The scripting layer, known as `Pyplot`, is suitable for everyday purposes. It simplifies common tasks and allows quick and easy generation of graphics and plots.
#
# ## Creating Plots with Pyplot
#
# The `Pyplot` interface automatically defines a Canvas and a Figure artist instance and connects them. Here's how to generate a histogram of 10,000 random numbers using the scripting layer:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Generate random data
# x = np.random.randn(10000)
#
# # Create histogram
# plt.hist(x, bins=100)
#
# # Show plot
# plt.show()
# ```
#
# In this example, `plt.hist` creates a sequence of rectangle artists for each histogram bar and adds them to the Axes container.
#
# ## Anatomy of a Plot
#
# The anatomy of a plot refers to the various components and elements that make up a visual representation of data. Key components include:
# - **Figure**: The overall window or canvas containing the plot(s).
# - **Axes**: The individual plots within a figure, providing scales and tick marks.
# - **Title**: A summary or explanation of the plot.
# - **Labels**: Descriptions of the data on each axis.
# - **Legend**: Explains the meaning of different elements or data series in the plot.
# - **Grid**: Helps align data points and read values.
# - **Annotations**: Provide supplemental information or explanations about specific data points or regions in the plot.
#
# You can customize the plot with different symbols, colors, and styles.
#
# For more detailed information, refer to the "Anatomy of a Figure" section on the official Matplotlib website. This guide provides a comprehensive overview of the components and elements that make up a plot.
#
# ## Summary
#
# In this video, you learned that Matplotlib is one of the most widely used data visualization libraries in Python. It was initially developed as an EEG and ECoG visualization tool. Matplotlib's architecture is composed of three main layers: the backend layer, the artist layer, and the scripting layer. The anatomy of a plot includes various components and elements that make up a visual representation of data.
#
# For further reading, consider exploring the chapter written by the creators of Matplotlib to learn more about its history and architecture.
# ```

# %% [markdown]
# # Basic Plotting with Matplotlib
#
# Welcome to Basic Plotting with Matplotlib. After watching this video, you'll be able to:
#
# - Explore how to use Matplotlib to create plots by employing Jupyter Notebook.
# - Create conventional visualization tools using the Plot function.
#
# Matplotlib is a well-established data visualization library that can be integrated into different environments such as Python scripts, Python and IPython shells, web application servers, and graphical user interface toolkits. The Jupyter Notebook is also one of them.
#
# ## Jupyter Notebook and Matplotlib
#
# The Jupyter Notebook is an open-source web application that allows you to create and share documents containing live code, visualizations, and explanatory text. Jupyter has specialized support for Matplotlib, making it easy to start visualizing data.
#
# ### Getting Started with Jupyter Notebook and Matplotlib
#
# 1. **Import Matplotlib**:
#    ```python
#    import matplotlib.pyplot as plt
#    ```
#
# 2. **Create a Plot**:
#    To plot a circular mark at position (5, 5):
#    ```python
#    plt.plot(5, 5, 'o')
#    plt.show()
#    ```
#
# 3. **Ensure Inline Plots**:
#    If plots are generated in a new popup window, you can enforce generating plots in the browser using the magic function:
#    ```python
#    %matplotlib inline
#    ```
#
# ### Matplotlib Backends
#
# Matplotlib has different backends available for rendering plots. The inline backend is commonly used in Jupyter Notebooks, but it has a limitation: you cannot modify a figure once it is rendered. To overcome this, you can use the notebook backend.
#
# #### Using the Notebook Backend
# With the notebook backend, you can modify a plot after it is rendered:
# ```python
# %matplotlib notebook
# ```
# This allows for interactive modifications, such as adding titles and labels after the plot is rendered.
#
# ### Example with Pandas
#
# Matplotlib integrates well with Pandas, making plotting in Pandas straightforward. Here's how to generate a line plot and histogram using a Pandas DataFrame:
#
# 1. **Import Pandas**:
#    ```python
#    import pandas as pd
#    ```
#
# 2. **Create a DataFrame**:
#    ```python
#    data = {
#        'Year': list(range(1980, 1997)),
#        'India': [1000, 2000, 3000, ...],  # example data
#        'China': [500, 1500, 2500, ...]   # example data
#    }
#    df = pd.DataFrame(data)
#    ```
#
# 3. **Line Plot**:
#    To plot a line plot for data from India and China:
#    ```python
#    df.plot(x='Year', y=['India', 'China'], kind='line')
#    plt.show()
#    ```
#
# 4. **Histogram**:
#    To plot a histogram of the India column:
#    ```python
#    df['India'].plot(kind='hist')
#    plt.show()
#    ```
#
# ### Summary
#
# In this video, you learned:
# - Matplotlib is a well-established data visualization library that can be integrated into different environments.
# - Jupyter Notebook is an open-source web application that allows you to create and share documents with live code and visualizations.
# - Matplotlib has multiple backends available for different use cases.
# - You can easily include labels and titles to your plots with Matplotlib.
#
# By using the plot function, you can create various conventional visualization tools such as histograms, bar charts, and box plots. Matplotlib's integration with Pandas simplifies the process of plotting data from data frames.
# ```
#
# **[MUSIC]**

# %% [markdown]
# # Welcome to Line Plots
#
# After watching this video, you'll be able to:
# - Describe a line plot and its function.
# - Determine when to use a line plot.
# - Create a line plot from data in a dataset.
#
# ## What is a Line Plot?
#
# A line plot displays information as a series of data points connected by straight lines. It is one of the most basic types of charts and is common in many fields, not just data science.
#
# ## When to Use a Line Plot
#
# Line plots are useful for:
# - Visualizing trends and changes over time, making them popular for time-series data such as stock prices, website traffic, or temperature fluctuations.
# - Showing relationships between two variables.
# - Comparing multiple data series on one chart.
# - Highlighting sudden changes or anomalies in data.
#
# ## Example: Line Plot of Immigration from Haiti to Canada
#
# We can generate a line plot to see the trend of immigrants from Haiti to Canada. For instance, a spike in immigration from Haiti to Canada in 2010 can be observed. Researching this anomaly reveals the tragic earthquake in Haiti in 2010, which led to increased immigration to Canada.
#
# ## How to Generate a Line Plot
#
# ### Step 1: Data Preparation
#
# Let's start by processing the dataset to make it easier to query specific countries and add a column for total immigration from 1980 to 2013.
#
# ### Step 2: Generate the Line Plot
#
# 1. **Import Matplotlib:**
#     ```python
#     import matplotlib.pyplot as plt
#     ```
#
# 2. **Plot the Data:**
#     ```python
#     df_canada.loc['Haiti'].plot(kind='line')
#     ```
#
# 3. **Add Title and Labels:**
#     ```python
#     plt.title('Immigration from Haiti to Canada (1980-2013)')
#     plt.xlabel('Year')
#     plt.ylabel('Number of Immigrants')
#     ```
#
# 4. **Display the Plot:**
#     ```python
#     plt.show()
#     ```
#
# ### Complete Code Example
#
# ```python
# # Import libraries
# import matplotlib.pyplot as plt
#
# # Assuming df_canada is your DataFrame
# df_canada = df_canada.set_index('Country')
#
# # Generate line plot for Haiti
# haiti_data = df_canada.loc['Haiti']
# haiti_data.plot(kind='line')
#
# # Add title and labels
# plt.title('Immigration from Haiti to Canada (1980-2013)')
# plt.xlabel('Year')
# plt.ylabel('Number of Immigrants')
#
# # Display plot
# plt.show()

# %% [markdown]
# # Quiz Questions and Solutions
#
# ## Question 1
#
# Matplotlib was created by:
#
# 1. James Gosling, a Canadian computer scientist.
# 2. Daniel Johnson, a German physicist.
# 3. Cleve Moler, an American mathematician and computer programmer.
# 4. John Hunter, an American neurobiologist.
#
# **Solution:**
# John Hunter, an American neurobiologist.
#
# ## Question 2
#
# True or False: Jupyter Notebook is an open-source web application that allows you to create and share documents.
#
# 1. True
# 2. False
#
# **Solution:**
# True
#
# ## Question 3
#
# What is the code for the Matplotlib magic function?
#
# 1. {%matplotlib}
# 2. ‘%matplotlib’
# 3. (%matplotlib)
# 4. %matplotlib
#
# **Solution:**
# %matplotlib
#
# ## Question 4
#
# Fill in the blank: A line plot is a series of _____ points connected by straight line segments.
#
# 1. Data
# 2. Connection
# 3. Matplotlib
# 4. Plotly
#
# **Solution:**
# Data
#
# ## Question 5
#
# What is the most widely used data visualization library in Python?
#
# 1. Pyplot
# 2. Plotly
# 3. Jupyter Notebook
# 4. Matplotlib
#
# **Solution:**
# Matplotlib
# ```

# %% [markdown]
# # Summary: Introduction to Data Visualization Tools
#
# Congratulations! You have completed this module. At this point in the course, you know:
#
# - **Data visualization** is the process of presenting data in a visual format, such as charts, graphs, and maps, to help people understand and analyze data easily.
#
# - **Use Cases**: Data visualization has diverse use cases, such as in business, science, healthcare, and finance.
#
# - **Best Practices**: It is important to follow best practices, such as selecting appropriate visualizations for the data being presented, choosing colors and fonts that are easy to read and interpret, and minimizing clutter.
#
# - **Types of Plots**:
#   - **Line Plots**: Capture trends and changes over time, allowing us to see patterns and fluctuations.
#   - **Bar Plots**: Compare categories or groups, providing a visual comparison of their values.
#   - **Scatter Plots**: Explore relationships between variables, helping us identify correlations or trends.
#   - **Box Plots**: Display the distribution of data, showcasing the median, quartiles, and outliers.
#   - **Histograms**: Illustrate the distribution of data within specific intervals, allowing us to understand its shape and concentration.
#
# - **Libraries**:
#   - **Matplotlib**: A plotting library that offers a wide range of plotting capabilities. One of the most widely used data visualization libraries in Python. It was initially developed as an EEG/ECoG visualization tool. Its architecture is composed of three main layers: Backend layer, Artist layer, and the Scripting layer.
#   - **Pandas**: Provides integrated plotting functionalities for data analysis.
#   - **Seaborn**: A specialized library for statistical visualizations, offering attractive default aesthetics and color palettes.
#   - **Folium**: Allows you to create interactive and customizable maps.
#   - **Plotly**: An interactive and dynamic library for data visualization that supports a wide range of plot types and interactive features.
#   - **PyWaffle**: Enables you to visualize proportional representation using squares or rectangles.
#
# - **Matplotlib Specifics**:
#   - The anatomy of a plot refers to the different components and elements that make up a visual representation of data.
#   - Matplotlib is a well-established data visualization library that can be integrated in different environments.
#   - **Jupyter Notebook**: An open-source web application that allows you to create and share documents.
#   - Matplotlib has a number of different backends available.
#   - You can easily include the label and title to your plot with `plt`.
#
# - **Data Handling**:
#   - To start creating different types of plots of the data, you will need to import the data into a **Pandas DataFrame**.
#   - A **line plot** is a plot in the form of a series of data points connected by straight line segments. It is one of the most basic types of chart and is common in many fields.
#   - You can generate a line plot by assigning "line" to the `kind` parameter in the `plot()` function.
# ```

# %% [markdown]
# # Quiz Questions and Solutions
#
# ## Question 1
#
# Matplotlib was created by:
#
# 1. Daniel Johnson, a German physicist
# 2. Cleve Moler, an American mathematician and computer programmer
# 3. John Hunter, an American neurobiologist
# 4. James Gosling, a Canadian computer scientist
#
# **Solution:**
# 3. John Hunter, an American neurobiologist
#
# ## Question 2
#
# True or False: Using the inline backend, you cannot modify a figure after it is rendered.
#
# 1. False
# 2. True
#
# **Solution:**
# 2. True
#
# ## Question 3
#
# Which two of the following are not examples of Matplotlib magic functions?
#
# 1. $matplotlib outline
# 2. %matplotlib notebook
# 3. #matplotlib inline
# 4. %matplotlib inline
#
# **Solution:**
# 1. $matplotlib outline
# 3. #matplotlib inline
#
# ## Question 4
#
# True or False: A line plot displays information as a series of data points connected by straight lines.
#
# 1. True
# 2. False
#
# **Solution:**
# 1. True
#
# ## Question 5
#
# True or False: Matplotlib's three main layers are: Backend, Artist, and Scripting.
#
# 1. True
# 2. False
#
# **Solution:**
# 1. True
#
# ## Question 6
#
# What is Jupyter Notebook used for?
#
# 1. It is a tool used for creating conventional visualization tools using the plot function
# 2. An open-source web application that allows you to create and share documents that contain live code, visualizations, and some explanatory text as well
# 3. A well-established data visualization library that can be integrated into different environments
# 4. A Python library with a number of different backends available
#
# **Solution:**
# 2. An open-source web application that allows you to create and share documents that contain live code, visualizations, and some explanatory text as well
#
# ## Question 7
#
# True or False: Matplotlib was initially developed as an EEG and ECoG visualization tool.
#
# 1. True
# 2. False
#
# **Solution:**
# 1. True
#
# ## Question 8
#
# True or False: The backend layer's three built-in interface classes are FigureCanvas, Renderer, and Event.
#
# 1. False
# 2. True
#
# **Solution:**
# 2. True
#
# ## Question 9
#
# What is the purpose of line plots?
#
# 1. Displays data trends over time
# 2. Line plots capture trends and changes over time, allowing us to see patterns and fluctuations.
# 3. Line plots capture data and changes overtime
# 4. Captures data from charts
#
# **Solution:**
# 2. Line plots capture trends and changes over time, allowing us to see patterns and fluctuations.
#
# ## Question 10
#
# True or False: Bar plots are ideal for comparing different categories or groups.
#
# 1. True
# 2. False
#
# **Solution:**
# 1. True
# ```
