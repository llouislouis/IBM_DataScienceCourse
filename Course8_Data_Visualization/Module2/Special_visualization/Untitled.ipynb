# %% [markdown]
# # Quiz Questions and Solutions
#
# ## Question 1
#
# What is a scatter plot?
#
# 1. A scatter plot represents the frequency distribution of a numeric dataset
# 2. A scatter plot is a type of plot that displays values pertaining to typically two variables against each other
# 3. A scatter plot is a circular statistical graphic divided into segments
# 4. A scatter plot displays the magnitude and proportion of multiple variables over a continuous axis
#
# **Solution:**
# 2. A scatter plot is a type of plot that displays values pertaining to typically two variables against each other
#
# ## Question 2
#
# True or False. Matplotlib is a general-purpose comprehensive plotting library that provides a flexible interface for creating a wide range of plots.
#
# **Solution:**
# True
#
# ## Question 3
#
# What is a pie chart?
#
# 1. A pie chart is a graphical representation that showcases the relative size and proportion of various variables along a continuous axis
# 2. A pie chart visually depicts the distribution of a numeric dataset by showcasing the frequency of each category
# 3. A pie chart is a circular statistical graphic divided into segments to illustrate numerical proportions
# 4. A pie chart is a type of plot in which the length of each bar is proportional to the value of the item that it represents
#
# **Solution:**
# 3. A pie chart is a circular statistical graphic divided into segments to illustrate numerical proportions
#
# ## Question 4
#
# A box plot is a way of statistically representing the distribution of given data through how many primary dimensions?
#
# 1. 8
# 2. 5
# 3. 3
# 4. 1
#
# **Solution:**
# 2. 5
#
# ## Question 5
#
# What is the first step when plotting with Matplotlib?
#
# 1. Call the subplot function
# 2. Import Pandas
# 3. Import matplotlib.pyplot as plt
# 4. Call the plot function
#
# **Solution:**
# 3. Import matplotlib.pyplot as plt
# ```

# %% [markdown]
# Summary: Basic and Specialized Visualization Tools
# Congratulations! You have completed this module. At this point in the course, you know:
#
# A pie chart is a circular statistical graphic, divided into segments, to illustrate numerical proportion.
#
# The process of creating a pie chart involves importing Matplotlib to represent a large set of data over a period of time.
#
# A box plot is a way of statistically representing given data distribution through five main dimensions.
#
# The five main dimensions are minimum, first quartile, median, third quartile, and maximum.
#
# You can create a box plot using Matplotlib.
#
# A scatter plot displays values pertaining to typically two variables against each other.
#
# The process of creating a scatter plot involves importing Matplotlib to visualize a large set of data.
#
# Matplotlib is a versatile plotting library that offers a flexible interface for creating various types of plots.
#
# Matplotlib’s Pyplot module offers a convenient way to create and customize plots quickly.
#
# Data Storytelling is the ‘art of storytelling’ that involves creating a narrative around the data.
#
# Data visualization is an important aspect of data storytelling and involves creating engaging visuals.

# %% [markdown]
# # Quiz Questions and Solutions
#
# ## Question 1
#
# True or False. A scatter plot is a type of plot that displays values pertaining to typically two variables?
#
# **Solution:**
# True
#
# ## Question 2
#
# True or False. When plotting directly with Matplotlib, the pyplot module offers a convenient way to create and customize plots quickly.
#
# **Solution:**
# True
#
# ## Question 3
#
# Fill in the blank. A pie chart is a circular statistical graphic, divided into _______, to illustrate numerical proportion.
#
# 1. Segments
# 2. Graphs
# 3. Plots
# 4. Columns
#
# **Solution:**
# 1. Segments
#
# ## Question 4
#
# How many primary dimensions does a box plot utilize to statistically represent the distribution of a given data?
#
# 1. 5
# 2. 4
# 3. 3
# 4. 1
#
# **Solution:**
# 1. 5
#
# ## Question 5
#
# Area plots are like a line plot but with the area below the line filled with color to emphasize the cumulative _______ of the variables.
#
# 1. Longitude
# 2. Magnitude
# 3. Significance
# 4. Latitude
#
# **Solution:**
# 2. Magnitude
#
# ## Question 6
#
# What do the letters in the box plot above represent?
#
# 1. A = Median, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, E = Minimum, and F = Outliers
# 2. A = Mean, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, E = Minimum, and F = Maximum
# 3. A = Mean, B = Upper Mean Quartile, C = Lower Mean Quartile, D = Inter Quartile Range, E = Minimum, and F = Outliers
# 4. A = Median, B = Third Quartile, C = Mean, D = Inter Quartile Range, E = Lower Quartile, and F = Outliers
#
# **Solution:**
# 1. A = Median, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, E = Minimum, and F = Outliers
#
# ## Question 7
#
# True or False. The correct combination of function and parameter to create a box plot in Matplotlib is Function = plot, and Parameter = kind with value = "box".
#
# **Solution:**
# True
#
# ## Question 8
#
# True or False. The first step when creating a histogram in Matplotlib is to import matplotlib as mpl and its scripting interface as plt.
#
# **Solution:**
# True
#
# ## Question 9
#
# True or False. The process of creating a scatter plot involves importing Matplotlib to visualize a large set of data.
#
# **Solution:**
# True
#
# ## Question 10
#
# True or False. A bar chart is also known as a Bar graph.
#
# **Solution:**
# True
# ```
