# %% [markdown]
# # Quiz Questions and Solutions
#
# ## Question 1
#
# Which application is a powerful data visualization library in Python, built primarily to help people visualize geospatial data?
#
# 1. Plotly
# 2. Folium
# 3. PyWaffle
# 4. Matplotlib
#
# **Solution:**
# 2. Folium
#
# ## Question 2
#
# Which Folium map style enables you to visualize natural vegetation colors?
#
# 1. Stamen terrain
# 2. Stamen toner
# 3. Open Street map
# 4. Street-level map
#
# **Solution:**
# 1. Stamen terrain
#
# ## Question 3
#
# True or False: With Folium, you can display multiple markers on a map.
#
# **Solution:**
# True
#
# ## Question 4
#
# Complete the following: To create a choropleth map of a region of interest, Folium requires a Geo JSON file that includes_________.
#
# 1. Statistical variable
# 2. The mapbox bright tiles set
# 3. df_Canada
# 4. Geospatial data of the region
#
# **Solution:**
# 4. Geospatial data of the region
#
# ## Question 5
#
# What is the first step when converting a world map into a choropleth map?
#
# 1. Apply the choropleth function
# 2. Use the columns "Country" and "Total" in our df_Canada dataframe
# 3. Define the variable
# 4. Use the country names to look up the geospatial information
#
# **Solution:**
# 3. Define the variable
# ```

# %% [markdown]
# # Summary: Advanced Visualizations and Geospatial Data
#
# Congratulations! You have completed this module. At this point in the course, you know:
#
# - **Folium** is a data visualization library in Python that helps people visualize geospatial data.
#
# - With Folium, you can create maps of different styles, such as street-level maps, stamen maps, and more.
#
# - A feature of Folium is that you can create different map styles using the **tiles** parameter.
#
# - With Folium, you can easily add markers on maps.
#
# - The **location** parameter specifies the latitude and longitude coordinates of the center point of the map.
#
# - Markers play a vital role in enhancing interactivity and adding context to maps.
#
# - The **folium.Marker()** function specifies location parameters.
#
# - The **popup** parameter provides a label upon being clicked.
#
# - Markers can be created using **feature group**.
#
# - A **choropleth map** is a thematic map in which areas are shaded or patterned in proportion to the measurement of the statistical variable.
#
# - When creating a choropleth map, Folium requires a **GeoJson** file that includes geospatial data of the region.
#
# - The **Mapbox Bright Tileset** displays the name of every country when used on a map.

# %% [markdown]
# 1.
# ### Question 1
# Although Seaborn is another data visualization library, it is based on _______.
#
# - Matplotlib
# - SciPy
# - Pandas
# - NumPy
#
# **Answer: Matplotlib**
#
# 2.
# ### Question 2
# What is the default map style in Folium?
#
# - Open Street Map
# - Stamen Toner
# - Stamen Terrain
# - Arial
#
# **Answer: Open Street Map**
#
# 3.
# ### Question 3
# The code for setting the initial zoom level in Folium is ______________.
#
# - (zoom_start) parameter
# - {zoom_start} parameter
# - zoom-start parameter
# - zoom_start=parameter
#
# **Answer: zoom_start=parameter**
#
# 4.
# ### Question 4
# True or False. The ‘location’ parameter specifies the latitude and longitude coordinates of the map’s center point.
#
# - False
# - True
#
# **Answer: True**
#
# 5.
# ### Question 5
# Which feature is vital in improving interactivity and adding context to maps?
#
# - Navigation
# - Zoom function
# - Markers
# - Locations
#
# **Answer: Markers**
#
# 6.
# ### Question 6
# A choropleth map is a _______ map.
#
# - Open Street Map
# - Stamen Toner
# - Thematic
# - Stamen Terrain
#
# **Answer: Thematic**
#
# 7.
# ### Question 7
# True or False. Folium is a Python library used for creating interactive maps and visualizations.
#
# - True
# - False
#
# **Answer: True**
#
# 8.
# ### Question 8
# True or False. To create a choropleth map of a region of interest, Folium requires a GeoJson file that includes geospatial data of the region.
#
# - True
# - False
#
# **Answer: True**
#
# 9.
# ### Question 9
# ______provides specialized plot types such as regression, distribution, and categorical plots that are particularly useful for analyzing data and modeling relationships.
#
# - Bar plot
# - Line plot
# - Seaborn
# - Pie plot
#
# **Answer: Seaborn**
#
# 10.
# ### Question 10
# ________ are a visualization technique that represents categorical data in the form of square tiles or cells.
#
# - Pie charts
# - Line charts
# - Bar charts
# - Waffle charts
#
# **Answer: Waffle charts**
# ```
