# %% [markdown]
# ### Question 1
# Which of the following is not true about Machine Learning?
#
# - [ ] Machine Learning models iteratively learn from data and allow computers to find hidden insights.
# - [ ] Machine Learning models help us in tasks such as object recognition, summarization, and recommendation.
# - [ ] Machine Learning was inspired by the learning process of human beings.
# - [x] Machine learning gives computers the ability to make decision by writing down rules and methods and being explicitly programmed.
#
# ### Question 2
# Which of the following is a Machine Learning technique?
#
# - [ ] Clustering
# - [ ] Classification
# - [ ] Regression/Estimation
# - [x] All of the above
#
# ### Question 3
# When would you use Multiple Linear Regression?
#
# - [x] When we would like to predict the impacts that weather and temperature have on crop yield.
# - [ ] Predict whether or not a customer switches to another brand based on income, education, etc.
# - [ ] Group genetic markers to identify family ties.
# - [ ] None of the above.
#
# ### Question 5
# Which of the following is an example of Logistic Regression?
#
# - [ ] The odds of a particular individual having a heart attack based on how much they exercise and how much they weigh.
# - [ ] The probability of a borrower defaulting on their mortgage based upon their credit score and age.
# - [ ] The probability of a person purchasing life insurance based on age and income.
# - [x] All of the above.
#
#
#
# ### Question 7
# Which one best describes the clustering process for k-means clustering?
#
# - [ ] k-means clustering creates a tree of clusters.
# - [ ] k-means creates clusters by grouping data points with similar labels.
# - [x] The objective of k-means is to form clusters in such a way that similar samples go into a cluster, and dissimilar samples fall into different clusters.
# - [ ] k-means divides the data into clusters with minimal overlap such that there are low chances of dissimilar samples in the same cluster.
#
# ### Question 8
# What is a hyperplane in SVM?
#
# - [ ] Data points
# - [ ] Features
# - [x] Decision boundaries
# - [ ] Classes
#
# ### Question 9
# In comparison to mean absolute error, mean squared error:
#
# - [x] Focuses more on large errors.
# - [ ] Is more interpretable by taking the same unit as the response.
# - [ ] Avoids cancellation of errors.
# - [ ] Weighs small and large errors equally.
#
# ### Question 10
# When do we use regression trees instead of decision trees?
#
# - [x] When the response is continuous instead of categorical
# - [ ] When the response is categorical instead of continuous
# - [ ] When some of the independent variables are continuous
# - [ ] When all of the independent variables are continuous

# %% [markdown]
# ### Question 1
# What is the subfield of computer science that gives "computers the ability to learn without being explicitly programmed"?
#
# - [ ] Graphics and visual computing
# - [x] Machine learning
# - [ ] Information management
# - [ ] Computational science
#
# ### Question 2
# Which of the following is a Machine Learning technique?
#
# - [ ] Clustering
# - [ ] Classification
# - [ ] Regression/Estimation
# - [x] All of the above
#
# ### Question 3
# In which of the following would you use Multiple Linear Regression?
#
# - [ ] Recommend products to customers based on their demographic characteristics.
# - [x] Predict CO2 emission of a car based on engine size.
# - [ ] Predicting the production of apples in an orchard based on temperature and rainfall.
# - [ ] Predict whether a customer is likely to repay a loan based on age and income.
#
# ### Question 4
# Which one is not an example of a classification problem?
#
# - [ ] To predict the category to which a customer belongs to.
# - [x] To predict the amount of money a customer will spend in one year.
# - [ ] To predict whether a customer responds to a particular advertising campaign or not.
# - [ ] To predict whether a customer switches to another provider/brand.
#
# ### Question 5
# Which of the following is an example of Logistic Regression?
#
# - [ ] The odds of a particular individual having a heart attack based on how much they exercise and how much they weigh.
# - [ ] The probability of a borrower defaulting on their mortgage based upon their credit score and age.
# - [ ] The probability of a person purchasing life insurance based on age and income.
# - [x] All of the above.
#
#
# ### Question 7
# Which one best describes the clustering process for k-means clustering?
#
# - [ ] k-means divides the data into clusters with minimal overlap such that there are low chances of dissimilar samples in the same cluster.
# - [ ] k-means clustering creates a tree of clusters.
# - [x] The objective of k-means is to form clusters in such a way that similar samples go into a cluster, and dissimilar samples fall into different clusters.
# - [ ] k-means creates clusters by grouping data points with similar labels.
#
# ### Question 8
# What is a hyperplane in SVM?
#
# - [ ] Data points
# - [x] Decision boundaries
# - [ ] Classes
# - [ ] Features
#
# ### Question 9
# Precision and recall are suitable for measuring the performance of which tasks?
#
# - [x] Classification
# - [ ] Clustering
# - [ ] Regression
# - [ ] All of the above
